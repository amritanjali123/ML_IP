# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('int.csv',header=None)

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 3].values

# %%
ls1=pd.Series(dataset[0])

# %%
ls1=ls1.tolist()

# %%
from googletrans import Translator

# %%
translator = Translator()

# %%
#ls = list(ls1.iloc[:, 0:5])
#ls=pd.Series(dataset[0])

# %%
ls1[0:10]
print(ls1)
list=[]
# Out:
# ['না', 'করে', 'থেকে', 'এই', 'এ', 'ও', 'হয়', 'এক', 'নিয়ে', 'ওই', 'হয়েছে', 'কিন্তু', 'হবে', 'করা', 'সঙ্গে', 'সেই', 'দিন', 'আর', 'যে', 'তিনি', 'তাঁর', 'বলে', 'তা', 'জন্য', 'কোনও', 'তার', 'বলেন', 'হয়ে', 'এবং', 'পুলিশ', 'করতে', 'অভিযোগ', 'কথা', 'একটি', 'ছিল', 'সব', 'শুরু', 'দাবি', 'পরে', 'যায়', 'এর', 'মধ্যে', 'তবে', 'সে', 'টাকা', 'দেওয়া', 'পর', 'ভাবে', 'কিছু', 'দিয়ে', 'হচ্ছে', 'করেন', 'বার', 'রয়েছে', 'বা', 'আগে', 'কী', 'কাজ', 'আরও', 'নেই', 'নয়', 'কাছে', 'গিয়েছে', 'তাঁদের', 'তো', 'জানান', 'জেলা', 'সময়', 'বছর', 'তাই', 'হল', 'করার', 'গত', 'এখন', 'মতো', 'দেখা', 'দলের', 'খবর', 'তৈরি', 'হলে', 'একটা', 'তাঁরা', 'বিরুদ্ধে', 'দিতে', 'পারে', 'জন', 'বেশি', 'আমরা', 'আমার', 'প্রায়', 'আমাদের', 'দিকে', 'নতুন', 'মনে', 'তৃণমূল', 'অনেক', 'আমি', 'শেষ', 'প্রথম', 'হয়েছিল', 'কি', 'অন্য', 'ধরে', 'দুই', 'করেছেন', 'বিভিন্ন', 'গিয়ে', 'টি', 'এমন', 'পর্যন্ত', 'এলাকায়', 'ভাল', 'ছিলেন', 'করেছে', 'তাঁকে', 'তিন', 'কেউ', 'রাজ্য', 'পুলিশের', 'তাদের', 'হয়নি', 'অবশ্য', 'র', 'কেন', 'নাম', 'আবার', 'আছে', 'সহ', 'হতে', 'স্থানীয়', 'কয়েক', 'থেকেই', 'হাতে', 'সেখানে', 'তৃণমূলের', 'বড়', 'সরকার', 'এখনও', 'ফলে', 'আজ', 'ব্যবস্থা', 'ঠিক', 'দেন', 'পড়ে', 'জানা', 'দেওয়ার', 'শুধু', 'বেশ', 'এলাকার', 'যাবে', 'তুলে', 'হাজার', 'তখন', 'সভাপতি', 'গেল', 'চলে', 'বন্ধ', 'নিজের', 'যা', 'দেখে', 'কংগ্রেস', 'সূত্রে', 'কথায়', 'সামনে', 'থাকে', 'কারণ', 'তারা', 'দল', 'করছেন', 'জল', 'সরকারি', 'প্রশ্ন', 'এসে', 'দিনের', 'সমস্যা', 'হওয়ার', 'মানুষ', 'যান', 'চেষ্টা', 'হাসপাতালে', 'নেতা', 'খুব', 'বাড়ি', 'নেওয়া', 'ফের', 'জানিয়েছেন', 'একই', 'দিয়েছেন', 'তাতে', 'থাকা', 'ঘটনা', 'নানা', 'রাতে', 'রাজ্যের', 'নামে', 'উপর', 'যদি', 'করছে', 'হিসেবে', 'যাচ্ছে', 'এত', 'ছবি', 'ভোট', 'বিজেপি', 'যেতে', 'বলছেন', 'বছরের', 'দেয়', 'দফতরের', 'চলছে', 'ক্ষেত্রে', 'চার', 'প্রধান', 'শহরের', 'যাওয়ার', 'গ্রেফতার', 'দুটি', 'সময়ে', 'কলকাতা', 'সেটা', 'সরকারের', 'জেলার', 'সিদ্ধান্ত', 'বাসিন্দা', 'বলা', 'কে', 'ঘটনার', 'নির্দেশ', 'নিতে', 'কম', 'দেশের', 'যখন', 'প্রার্থী', 'কেন্দ্রীয়', 'মানুষের', 'দিয়েছে', 'লক্ষ', 'হাত', 'নম্বর', 'মুখ্যমন্ত্রী', 'হলেও', 'পারেন', 'কর্মী', '•', 'পাওয়া', 'প্রতি', 'টাকার', 'যেন', 'গ্রামের', 'উত্তর', 'দেখতে', 'বহু', 'পেয়ে', 'সূত্রের', 'আগেই', 'যদিও', 'মুখে', 'পঞ্চায়েত', 'বিষয়টি', 'বক্তব্য', 'ভারতীয়', 'সংস্থার', 'বাড়িতে', 'বিশেষ', 'পাঁচ', 'সাধারণ', 'ছাড়া', 'পাশাপাশি', 'এটা', 'সালে', 'হন', 'শুক্রবার', 'কোটি', 'রাস্তা', 'সম্পাদক', 'শনিবার', 'রকম', 'যোগ', 'কংগ্রেসের', 'বুধবার', 'জানিয়েছে', 'সোমবার', 'ভারত', 'রবিবার', 'ভারতের', 'মঙ্গলবার', 'সিপিএম', 'কাজে', 'রাখা', 'গোটা', 'বাইরে', 'যাওয়া', 'করেছিলেন', 'যেমন', 'বৃহস্পতিবার', 'পরিবারের', 'বিধায়ক', 'সকালে', 'জাতীয়', 'মমতা', 'উপরে', 'রায়', 'বসে', 'মা', 'গাড়ি', 'তরফে', 'দফতর', 'বলতে', 'প্রাক্তন', 'বাবা', 'সিপিএমের', 'ঘটনায়', 'কখনও', 'জানিয়ে', 'সদস্য', 'ছোট', 'মাস', 'বললেন', 'রাত', 'জায়গায়', 'বিষয়ে', 'একটু', 'পরেই', 'ভোটের', 'কমিটির', 'আসে', 'জমি', 'মুখ', 'থানার', 'চালু', 'জমা', 'সম্ভব', 'আগামী', 'পরিস্থিতি', 'ঘোষণা', 'ফিরে', 'প্রাথমিক', 'গেলে', 'মৃত্যু', 'রাজনৈতিক', 'পুরসভার', 'পুজো', 'যাতে', 'গ্রামে', 'জানানো', 'বাড়ির', 'উদ্ধার', 'পাশে', 'ব্যবহার', 'ভেঙে', 'স্কুল', 'নিজেদের', 'কেন্দ্র', 'তথা', 'পথে', 'সংস্থা', 'মন্ত্রী', 'মাত্র', 'টা', 'জানতে', 'বলেছেন', 'থাকবে', 'শিক্ষক', 'করলেন', 'উঠে', 'মহিলা', 'সকাল', 'সিংহ', 'রাস্তায়', 'ধরা', 'গ্রাম', 'হওয়া', 'প্রশাসনের', 'রেখে', 'মধ্যেই', 'এখানে', 'প্রশাসন', 'নাগাদ', 'ভর্তি', 'করবে', 'সুযোগ', 'সম্প্রতি', 'মাঠে', 'ম্যাচ', 'পুজোর', 'ব্যাপারে', 'দক্ষিণ', 'দিলেন', 'করবেন', 'কারণে', 'বিধানসভা', 'রাজ্যে', 'মোদী', 'ব্লক', 'স্কুলের', 'আসা', 'থাকতে', 'ধরনের', 'তদন্ত', 'কর্মীদের', 'কলকাতার', 'তাকে', 'দ্বিতীয়', 'চেয়ে', 'নোট', 'স্বাস্থ্য', 'কোন', 'ছেলে', 'কলেজ', 'দ্রুত', 'ছাত্র', 'মেনে', 'রাখতে', 'দায়িত্ব', 'এলাকা', 'রয়েছেন', 'মাথায়', 'বিরোধী', 'করল', 'বলেই', 'বন্দ্যোপাধ্যায়', 'যার', 'উঠেছে', 'তৈরির', 'ফোন', 'বাকি', 'কিছুটা', 'গিয়েছিল', 'অথচ', 'নেওয়ার', 'অনেকেই', 'হোক', 'দিনে', 'এগিয়ে', 'নেমে', 'শহরে', 'ই', 'ছেড়ে', 'নাকি', 'পরীক্ষা', 'সমিতির', 'সুপার', 'থাকার', 'থানায়', 'ঘরে', 'বৈঠকে', 'কোথাও', 'এসেছে', 'জেরে', 'করলে', 'আদালতে', 'দাস', 'শাসক', 'বৈঠক', 'বাজারে', 'খরচ', 'মন্তব্য', 'পুরনো', 'তথ্য', 'বিক্রি', 'জনের', 'হয়েছেন', 'কাজের', 'সমস্ ...

# %%
k=0
for i in range(1, 2): 
    translations = translator.translate(ls1[k:100+k], dest='en')
    k=k+100
    for translation in translations:
        print(translation.text)
# Out:
# Not
# And
# From
# this
# This
# Re
# Is
# One
# With
# That
# Have
# But
# Will
# Make
# With
# That
# Day
# More
# That
# She
# His
# Says
# But
# For
# No
# His
# The
# The
# And
# Police
# To
# Complaint
# Word
# A
# Was
# Everything
# Start
# Claim
# Then
# The
# Of
# In
# Then
# She
# Money
# Provided
# After
# Way
# Some
# With
# Getting
# The
# Bar
# There
# Or
# Before
# What
# Work
# More
# There
# Not
# To
# It has
# Their
# The
# Tell
# District
# Time
# Year
# Therefore,
# Hall
# To
# Last
# now
# Like
# See
# Group
# News
# Create
# When
# A
# They
# Against
# Pay
# Can
# person
# Much
# We
# My
# Almost
# Our
# On
# New
# Think
# TMC
# Many
# I
# Last
# First
# It was

# %%
    
#...    print(translation.origin, ' -> ', translation.text)

# %%
list

# %%
df = pd.DataFrame(list)

# %%
csv_data = df.to_csv(index=False)

# %%
df.to_csv('inte1.csv', index=False)
